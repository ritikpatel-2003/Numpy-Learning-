# %%
import numpy as np
# Data structure: [restaurant_id, 2021, 2022, 2023, 2024]

sales_data = np.array([
    [1, 150000, 180000, 220000, 250000],  # Paradise Biryani
    [2, 120000, 140000, 160000, 190000],  # Beijing Bites
    [3, 200000, 230000, 260000, 300000],  # Pizza Hub
    [4, 180000, 210000, 240000, 270000],  # Burger Point
    [5, 160000, 185000, 205000, 230000]   # Chai Point
])

# %% [markdown]
# ## Finding the shape of the data

# %%
print("Shape of the sales Data: ", sales_data.shape)
# Out:
# Shape of the sales Data:  (5, 5)

# %% [markdown]
# ## Finding the data of first 3 restraunt

# %%
print("The required data is: ", sales_data[0:3])
# Out:
# The required data is:  [[     1 150000 180000 220000 250000]
#  [     2 120000 140000 160000 190000]
#  [     3 200000 230000 260000 300000]]

# %% [markdown]
# ## Total Sales Per year

# %%
print("Total sale per Year: ", (np.sum(sales_data, axis = 0)))
yearly_sale  =  np.sum(sales_data[:,1:], axis = 1)
print(yearly_sale)
# Out:
# Total sale per Year:  [     15  810000  945000 1085000 1240000]
# [800000 610000 990000 900000 780000]

# %% [markdown]
# ## Minimum sales  per restraunt

# %%
print("Minimum sales of Paradise Biryani: ", np.min(sales_data[:,1:], axis= 1))
# Out:
# Minimum sales of Paradise Biryani:  [150000 120000 200000 180000 160000]

# %% [markdown]
# ## Maximum Sale per year

# %%
print("Maximum sale in a year: ",  np.max(sales_data[:, 1:], axis = 0))
# Out:
# Maximum sale in a year:  [200000 230000 260000 300000]

# %% [markdown]
# ## Average Sale per restraunt

# %%
print("Average Sales of Restraunt: ", np.average(sales_data[:,1:],axis = 1))
# Out:
# Average Sales of Restraunt:  [200000. 152500. 247500. 225000. 195000.]
